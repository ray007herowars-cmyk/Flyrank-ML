# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ray007herowars-cmyk/Flyrank-ML/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# I am continuing with the Refresh / Content Opportunity Scoring lane.
#
# The ML task is **ranking/scoring**. The goal is to rank content items by how strongly they should be considered for editorial review, so that an editor can review the highest-priority items first.
#
# The output is therefore a priority score or ranked list for each content item. The practical decision is not simply whether a page is "good" or "bad", but which pages deserve limited editorial attention first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# For the eventual model, I would prefer an observed downstream outcome rather than a rule-defined label.
#
# A possible target is whether a content item shows a meaningful improvement in a later performance window after being refreshed, provided that the dataset gives us a valid way to identify the refresh and the later outcome.
#
# For the Week 2 framing stage, I will use a **proxy target** only to explore the problem. The starter dataset's observed performance-change fields can help identify whether there is a useful population to investigate, but `trend_pct`, `trend_direction`, and `is_declining_label` will not be used as model features.
#
# The final target will be revisited once the available time windows and intervention information are checked.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# The main success metric will be **precision@K**.
#
# This matches the real decision because an editor has limited review capacity. If the system produces a top-K review queue, precision@K measures how many of those highest-ranked items actually meet the chosen observed outcome.
#
# I will compare the ML ranking against a simple baseline. ML is only useful if it provides better prioritization than that baseline.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# The unit of analysis is **one content item/page**.
#
# Each row represents one pseudonymized content item. The columns contain attributes and performance signals associated with that item. This grain matches the editorial decision because an editor ultimately chooses which individual pages to review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

data_path = "Flyrank-ML/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(data_path)

# Show the unit of analysis as actual rows.
unit_df = df[
    [
        "content_id",
        "content_type",
        "main_intent",
        "word_count",
        "impressions_90d",
        "impressions_last_30d",
        "clicks_90d",
        "clicks_last_30d"
    ]
].head(10)

unit_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_792/2242492928.py in <cell line: 0>()
#       5 data_path = "Flyrank-ML/data/raw/content_refresh_anonymized.csv"
#       6
# ----> 7 df = pd.read_csv(data_path)
#       8
#       9 # Show the unit of analysis as actual rows.
#
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule would be a useful baseline, but it may become difficult to maintain if several signals interact. Content performance can involve search demand, impressions, clicks, average position, content characteristics, intent, and other signals that may have different relationships across content items.
#
# ML is worth testing if it can learn useful combinations of these signals and produce a better top-K review ranking than a simple rule.
#
# However, I will not assume that ML wins. The baseline rule will be evaluated using the same metric, precision@K. If ML does not improve the ranking, a simpler rule may be the better solution.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
